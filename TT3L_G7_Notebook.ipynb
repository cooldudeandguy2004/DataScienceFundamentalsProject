# %% [markdown]
# <a href="https://colab.research.google.com/github/cooldudeandguy2004/DataScienceFundamentalsProject/blob/main/TT3L_G7_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # README
#
# **Project Title:** Global Sustainable Energy Transition and CO₂ Emissions Analysis from 2000 to 2020
#
# **Tutorial section:** TT3L
#
# **Group:** 7
#
# <div align="left">
#
# | | Student ID     | Student Name                | Contribution |
# |--:|:-------------|:----------------------------|-------------:|
# | 1 | 1211112009  | Azib bin Azendi | 25% |
# | 2 | 1211110444  | Mohammad Hazman bin Khairil Anwar | 25% |
# | 3 | 1211112341 | Muhammad Ammar Muqriz bin Mohd Rizal | 25% |
# | 4 | 241UC240WF | Muhammad Luqman Hakim bin Derela | 25% |
#
# </div>
#
# Note: Marks may vary among group members based on individual contributions. Ensure all members agree on the contribution percentages listed here.
#
# ---
#
# **YouTube link:**
# [Paste the unlisted YouTube presentation link here after recording]
#
# Please note that the examiner will not notify you if your video link is unavailable, inaccessible, or incorrectly provided. It is the responsibility of the group to ensure that the video link is fully functional and accessible at the time of assessment. Failure to provide a valid and working link will result in a score of zero (0) marks for the presentation component.
#
# ---
#
# **Dataset Title:**
# Global Data on Sustainable Energy (2000–2020)
#
# **Source & Link:**
# Kaggle — Global Data on Sustainable Energy
# https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy
#
# **Dataset Citation:**
# Tanwar, A. (2023). *Global Data on Sustainable Energy*. Kaggle.
# https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy
#
# **License:**
# Apache-2.0 License
#
# **Download instructions:**
# 1. Go to the Kaggle dataset page using the link above.
# 2. Sign in to Kaggle if required.
# 3. Click **Download**.
# 4. Extract the downloaded file if it is compressed.
# 5. Place the CSV file inside the `./data/` folder.
# 6. Rename the file as `global-data-on-sustainable-energy.csv`.
#
# **Brief Description:**
# This dataset includes global sustainable energy indicators for the years 2000 - 2020 for countries around the world. It comprises of variables like access to electricity, access to clean fuels for cooking, share of renewable energy, share of electricity generation from fossil fuels and renewables, share of low-carbon electricity generation, energy intensity, GDP per capita and CO₂ emissions. The dataset can be used for the TT3L domain, Environment, Climate & Sustainability, as it can be analysed in relation with sustainable energy transition, energy efficiency and energy-related emissions.
#
# **Problem Statement:**
# Access to reliable energy and reduction in fossil fuel consumption and carbon emissions are areas of focus that many countries are attempting to improve upon. However, there are variations in progress between countries in terms of energy infrastructure, use of renewables, economic development and energy efficiency. This project aims to use global sustainable energy data between 2000 and 2020 to detect trends, relationships, predicting factors and country clusters that can help to improve the sustainability and climate-related decision-making process.
#
# **Analytical Questions:**
# Q1. What are the trends of global sustainable energy indicators from 2000 to 2020?
#
# Q2. Are there significant differences in clean energy access and energy intensity between countries of different per capita GDP?
#
# Q3. What are some indicators of energy and economy that can foretell CO₂ emissions?
#
# Q4. Are countries able to be clustered by their sustainable energy profiles?
#
# **How to Run:**
# 1. Place the dataset file inside the `./data/` folder.
# 2. Make sure the file name is exactly `global-data-on-sustainable-energy.csv`.
# 3. Run the notebook from top to bottom without skipping any cells.

# %% [markdown]
# ## 1. Introduction & Problem Statement
#
# Sustainable energy is necessary because countries require reliable energy access, with minimal impact on the environment and carbon emissions. High fossil fuel-based energy systems can lead to increased CO₂ emissions and renewable and low carbon electricity systems can help achieve climate and sustainability targets.
#
# This project is based on indicators of sustainable energy worldwide, covering the time period 2000-2020. This analysis can be performed using the dataset because it provides country-level data on electricity access, clean cooking access, share of renewable energy in electricity generation, electricity generation sources, low carbon electricity generation, energy intensity, GDP per capita, and CO₂ emissions.
#
# ### Problem Statement
#
# There is a global push for greater access to reliable energy, less reliance on fossil fuels and fewer carbon emissions. Yet, advancement varies from one country to another, resulting from variations in energy infrastructure, renewable energy adoption, economic development and energy efficiency. This project aims to analyse global sustainable energy data between 2000 and 2020 in order to find trends and relationships, prediction factors and country groups that can help in better decision making for sustainable energy and climate.
#
# ### Analytical Questions
#
# Q1. What are the trends of global sustainable energy indicators from 2000 to 2020?
#
# Q2. Are there significant differences in clean energy access and energy intensity between countries of different per capita GDP?
#
# Q3. What are some indicators of energy and economy that can foretell CO₂ emissions?
#
# Q4. Are countries able to be clustered by their sustainable energy profiles?

# %% [markdown]
# ## 2. Data Source & Understanding
#
# ### Data Source
#
# This project employs the dataset, Global Data on Sustainable Energy. It has been downloaded from the open data platform Kaggle. It provides country indicators related to sustainable energy from 2000 to 2020.
#
# ### Dataset Description
#
# Each row in the dataset is a country or entity in a given year. The data comprises indicators on:
#
# - Access to electricity
# - Access to safe cooking fuels.
# - Renewable electricity capacity
# - Renewable energy share
# - Electricity generation from fossil fuels, nuclear and renewables
# - Low-carbon electricity percentage
# - Primary energy consumption per capita (HEJ/mwhr)
# - Energy intensity
# - CO₂ emissions
# - GDP growth and GDP per capita.
# - Population density, land area, latitude, and longitude
#
# ### Dataset Suitability
#
# This dataset can be used for the TT3L domain, Environment, Climate & Sustainability, as it directly contributes to analysing sustainable energy transition, the adoption of renewable energy, energy efficiency and CO₂ emissions.
#
# ### Dataset Limitations
#
# There are missing values in some columns, particularly those that measure financial flows and renewable energy equivalent primary energy. Therefore, not all the variables are suitable for all types of analysis. The country-level nature of the data also means that it does not provide detailed information on energy use at the local, household, or individual level.

# %% [markdown]
# ## 3. Initial Data Checks
# - Shape, columns, dtypes
# - Sample rows (head/tail)
# - Basic summary statistics

# %%
import sys
import random
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)

print("Libraries imported successfully.")

print("\nPython version:")
print(sys.version)

print("\nLibrary versions:")
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)

df_raw = pd.read_csv("./data/global-data-on-sustainable-energy.csv")

print("\nDataset loaded successfully.")
print("Number of rows:", df_raw.shape[0])
print("Number of columns:", df_raw.shape[1])
# Out:
# Libraries imported successfully.
#
# Python version:
# 3.14.3 | packaged by conda-forge | (main, Feb  9 2026, 21:56:48) [MSC v.1944 64 bit (AMD64)]
#
# Library versions:
# NumPy: 2.4.4
# Pandas: 3.0.2
# Matplotlib: 3.10.9
# Seaborn: 0.13.2
#
# Dataset loaded successfully.
# Number of rows: 3649
# Number of columns: 21

# %%
from IPython.display import display
print("First five rows:")
display(df_raw.head())

print("Last five rows:")
display(df_raw.tail())

print("Dataset shape:", df_raw.shape)

print("Number of countries/entities:", df_raw["Entity"].nunique())

print("Year range:", df_raw["Year"].min(), "to", df_raw["Year"].max())

print("\nColumn names:")
for col in df_raw.columns:
    print("-", col)

print("\nData types:")
display(df_raw.dtypes)

print("\nSummary statistics:")
display(df_raw.describe())

print("\nMissing values:")
missing_values = df_raw.isnull().sum().sort_values(ascending=False)
display(missing_values)

duplicate_count = df_raw.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)

summary_table = pd.DataFrame({
    "Item": [
        "Number of rows",
        "Number of columns",
        "Number of countries/entities",
        "Start year",
        "End year",
        "Duplicate rows"
    ],
    "Value": [
        df_raw.shape[0],
        df_raw.shape[1],
        df_raw["Entity"].nunique(),
        df_raw["Year"].min(),
        df_raw["Year"].max(),
        duplicate_count
    ]
})

print("\nDataset summary table:")
display(summary_table)

data_dictionary = pd.DataFrame({
    "Column": [
        "Entity",
        "Year",
        "Access to electricity (% of population)",
        "Access to clean fuels for cooking",
        "Renewable-electricity-generating-capacity-per-capita",
        "Financial flows to developing countries (US $)",
        "Renewable energy share in the total final energy consumption (%)",
        "Electricity from fossil fuels (TWh)",
        "Electricity from nuclear (TWh)",
        "Electricity from renewables (TWh)",
        "Low-carbon electricity (% electricity)",
        "Primary energy consumption per capita (kWh/person)",
        "Energy intensity level of primary energy (MJ/$2017 PPP GDP)",
        "Value_co2_emissions_kt_by_country",
        "Renewables (% equivalent primary energy)",
        "gdp_growth",
        "gdp_per_capita",
        "Density\\n(P/Km2)",
        "Land Area(Km2)",
        "Latitude",
        "Longitude"
    ],
    "Description": [
        "Country or entity name",
        "Year of observation",
        "Percentage of population with access to electricity",
        "Percentage of population with access to clean fuels for cooking",
        "Renewable electricity generating capacity per person",
        "Financial flows to developing countries for clean energy support",
        "Renewable energy share in total final energy consumption",
        "Electricity generated from fossil fuels in terawatt-hours",
        "Electricity generated from nuclear sources in terawatt-hours",
        "Electricity generated from renewable sources in terawatt-hours",
        "Percentage of electricity generated from low-carbon sources",
        "Primary energy consumption per person in kWh/person",
        "Energy intensity measured as MJ per $2017 PPP GDP",
        "CO₂ emissions by country in kilotonnes",
        "Renewables as percentage of equivalent primary energy",
        "Annual GDP growth",
        "Gross domestic product per person",
        "Population density per square kilometre",
        "Land area in square kilometres",
        "Latitude coordinate",
        "Longitude coordinate"
    ]
})

print("\nData dictionary:")
display(data_dictionary)

df = df_raw.copy()

print("Working copy created successfully.")
print("Use df or df.copy() in later sections. Do not reload the dataset.")
# Out:
# First five rows:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %% [markdown]
# ## 4. Data Cleaning & Preprocessing
# - Handle missing values (strategy and justification)
# - Fix types (dates, categoricals, numerics)
# - Remove/flag outliers
# - Feature engineering (document purpose)
# - Keep transformations transparent and reproducible

# %%
# 1. Standardize Column Names
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_', regex=False)
    .str.replace('/', '_', regex=False)
    .str.replace('(', '', regex=False)
    .str.replace(')', '', regex=False)
    .str.replace('%', 'pct', regex=False)
    .str.replace('$', 'usd', regex=False)
    .str.replace(r'\\n', '_', regex=True)
)

# 2. Fix Data Types
# 'density_p_km2' was loaded as an object due to commas (e.g. '1,234'). Convert to float.
df['density_p_km2'] = df['density_p_km2'].astype(str).str.replace(',', '', regex=False).astype(float)

# 3. Handle Missing Values
print("Missing values before cleaning:\n", df.isnull().sum())

# Drop columns with excessive missing values (>50%)
missing_threshold = len(df) * 0.5
df = df.dropna(thresh=missing_threshold, axis=1)

# Impute remaining numerical columns
import numpy as np
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    if df[col].isnull().sum() > 0:
        # Impute with country median first
        df[col] = df[col].fillna(df.groupby('entity')[col].transform('median'))
        # If a whole country is NaN, fallback to global median
        df[col] = df[col].fillna(df[col].median())

print("\nMissing values after cleaning:\n", df.isnull().sum())

# 4. Check for duplicates
print("\nDuplicates before cleaning:", df.duplicated().sum())
df = df.drop_duplicates()
print("Duplicates after cleaning:", df.duplicated().sum())
# Out:
# Missing values before cleaning:
#  entity                                                                 0
# year                                                                   0
# access_to_electricity_pct_of_population                               10
# access_to_clean_fuels_for_cooking                                    169
# renewable-electricity-generating-capacity-per-capita                 931
# financial_flows_to_developing_countries_us_usd                      2089
# renewable_energy_share_in_the_total_final_energy_consumption_pct     194
# electricity_from_fossil_fuels_twh                                     21
# electricity_from_nuclear_twh                                         126
# electricity_from_renewables_twh                                       21
# low-carbon_electricity_pct_electricity                                42
# primary_energy_consumption_per_capita_kwh_person                       0
# ...

# %% [markdown]
# ### Data Cleaning Justification (Member 2)
#
# Data cleaning justification is handled by Member 2.Member 2 is responsible for data cleaning justification.
#
# **1. Standardizing Column Names:**
# All column names were converted to lowercase, whitespaces stripped and replaced with underscores and special characters. It eliminates syntax errors, and makes it easier to access columns by either the . notation or by a dictionary key in the analysis.
#
# **2. Fixing Data Types:**
# The population density column (`density_p_km2`) was imported as an `object` data type because the thousands separator used in the data was a comma (e.g., `1,234`). We stripped out the commas and cast the column to `float` so that we could perform numerical operations.
#
# **3. Handling Missing Values:**
# - **Column Dropping:** We excluded any columns having more than half of the data missing (Column Dropping). Then there would be too much noise, and it would lead us astray.
# - **Imputation:** For the missing numerical values, we attempted to impute using the median of that particular country to ensure geographic and economic consistency. If there was no data for that column at all, then we used the global median to keep the row being used, but not altering the global distribution significantly.
#
# **4. Duplicates:**
# We performed a duplicate check and eliminated any duplicate rows to avoid double counting.

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
# - Univariate distributions
# - Bivariate relationships
# - Correlations/associations
# - Well-labeled, readable plots with units where applicable

# %%
plt.figure(figsize=(15, 5))

# 1. Distribution of Access to Electricity
plt.subplot(1, 2, 1)
sns.histplot(df['access_to_electricity_pct_of_population'], bins=30, kde=True, color='orange')
plt.title('Distribution of Access to Electricity (%)')
plt.xlabel('Access to Electricity (%)')
plt.ylabel('Frequency')

# 2. Correlation between GDP and Primary Energy Consumption
plt.subplot(1, 2, 2)
sns.scatterplot(data=df, x='gdp_per_capita', y='primary_energy_consumption_per_capita_kwh_person', alpha=0.5)
plt.title('GDP per Capita vs. Energy Consumption')
plt.xlabel('GDP per Capita (USD)')
plt.ylabel('Primary Energy Consumption (kWh/person)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### EDA Interpretation (Member 2)
# The exploratory visualizations above reveal some key structural characteristics of the global sustainable energy dataset:
# - **Access to Electricity (Left):** The distribution is heavily left-skewed. This indicates that the vast majority of countries in our dataset have achieved near 100% electricity access for their populations. However, the long tail extending to the left highlights that there is still a significant subset of developing nations struggling with energy access.
# - **GDP vs Energy Consumption (Right):** There is a clear positive, non-linear correlation between a country's wealth (GDP per Capita) and its primary energy consumption. Wealthier nations consume vastly more energy per person. The dense clustering at the bottom left represents developing nations, emphasizing the gap in industrialization and energy usage globally.

# %% [markdown]
# ## 6. Modeling / Deeper Analysis (if applicable)
# - Define task (prediction, classification, clustering, inference, etc.)
# - Train/test split or cross-validation
# - Baselines, metrics, and parameter choices
# - Control randomness with fixed seeds

# %% [markdown]
# ## 7. Performance Evaluation and Enhancement (if applicable)

# %% [markdown]
# ## 8. The FOUR Analytical Questions
# - Answer each questions with supporting facts from the data analysis.
# - Use visuals for clearer communication whenever possible.

# %% [markdown]
# ### Q1: Trend Analysis (Member 2)
# **Question:** How has the global share of renewable energy consumption and electricity generated from renewables trended from 2000 to 2020?

# %%
# Group by Year to see global trends
global_trend = df.groupby('year')[['renewable_energy_share_in_the_total_final_energy_consumption_pct', 'electricity_from_renewables_twh']].mean().reset_index()

plt.figure(figsize=(12, 5))

# Plot 1: Renewable Energy Share
plt.subplot(1, 2, 1)
sns.lineplot(data=global_trend, x='year', y='renewable_energy_share_in_the_total_final_energy_consumption_pct', marker='o')
plt.title('Global Trend: Renewable Energy Share (%)')
plt.ylabel('Share of Total Consumption (%)')

# Plot 2: Electricity from Renewables
plt.subplot(1, 2, 2)
sns.lineplot(data=global_trend, x='year', y='electricity_from_renewables_twh', marker='o', color='green')
plt.title('Global Trend: Electricity from Renewables (TWh)')
plt.ylabel('TWh')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Results & Interpretation
# - Summarize key findings
# - Discuss insights generated from the data analysis and modeling
# - Present the most informative visuals/tables with clear captions
# - Relate results back to the research questions

# %% [markdown]
# ### Q1: Trend Analysis Findings (Member 2)
# **Question:** How has the global share of renewable energy consumption and electricity generated from renewables trended from 2000 to 2020?
#
# **Interpretation & Conclusion:**
# Based on the global trend charts generated in Section 8:
# 1. **Massive Growth in Output:** Global electricity generated from renewable sources saw significant growth, more than doubling from an average of roughly **14.8 TWh per country in 2000** to nearly **39.8 TWh by 2020**. This indicates a strong global shift towards building renewable infrastructure (like solar, wind, and hydro).
# 2. **Flat Share in Consumption:** Interestingly, despite the massive absolute increase in renewable energy production, the actual **share** of renewable energy in the total final energy consumption remained relatively flat (and even dipped slightly between 2000 and 2010 before recovering).
# 3. **Insight:** This suggests that while countries are rapidly generating more green electricity, global overall energy demand (driven by population growth, industrialization, and fossil fuel consumption) grew just as fast. The transition to a green grid is happening in absolute terms, but fossil fuels still dominate the growth of overall global energy demand.

# %% [markdown]
# ## 10. Conclusions & Limitations
# - What did you learn?
# - What are limitations and possible biases?
# - What are logical next steps or improvements?

# %% [markdown]
# ## References
# - Any academic articles, blogs, or documentation used
# - All references in APA format only
# - Citation in text example: The field of natural language processing has become dominated by deep learning approaches (Young et al., [2018](https://doi.org/10.1109/MCI.2018.2840738)).
# - Citation example in the list:
#     - [Python Docs](https://docs.python.org/3/)
#     - [Python Tutorial](https://docs.python.org/3/tutorial/index.html)

# %% [markdown]
# ## Academic Integrity
#
# - Work must be your own. If you use code snippets or ideas from references, cite them in the notebook.
# - Do not include copyrighted data not permitted for redistribution.

# %% [markdown]
# ## Plagiarism
# It is fine to seek help from friends or from online resources when you do the assignment, However,
# seeking help should not go overboard, to the point of getting (or even paying) someone to
# complete the assignment partly or fully for you, copying from online resources without
# understanding, or doing any means with the intention to cheat.
#
# For this assignment, plagiarism
# means the following:
# (a) Turning in a work that, from the examiner’s point of view, you do not sufficiently understand.
# (b) Turning in someone else’s work (whether partly or fully) as your own.
# (c) To use another’s work (whether partly or fully) without crediting the source.
# (d) Any means of cheating.
#
# **Plagiarism is a serious offence.**
#
# **We will give ZERO (0) marks to students who plagiarize AND to students who intentionally or
# unintentionally help other students to plagiarize by giving all or some of their code.**

# %% [markdown]
# ## Final Self‑Checklist (before submitting)
#
# * [ ] Rename your Jupyter Notebook file according to your group number
# * [ ] All items in README section are filled up
# * [ ] All group members' ID, name, and contribution fill-in.
# * [ ] Dataset link is from a recognized source and publicly accessible
# * [ ] YouTube link is accessible.
# * [ ] Notebook runs end‑to‑end with no manual steps beyond placing data files
# * [ ] Dataset loaded once only
# * [ ] No absolute paths; only relative paths used
# * [ ] All figures have titles/labels; text and tables are readable
# * [ ] Methods and choices are explained and justified
# * [ ] References properly cited
# * [ ] Notebook is clear, professional, and run within reasonable runtime
