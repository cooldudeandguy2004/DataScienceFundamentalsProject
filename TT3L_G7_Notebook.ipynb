# %% [markdown]
# <a href="https://colab.research.google.com/github/cooldudeandguy2004/DataScienceFundamentalsProject/blob/main/TT3L_G7_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # README
#
# **Project Title:** Global Sustainable Energy Transition and CO₂ Emissions Analysis from 2000 to 2020
#
# **Tutorial section:** TT3L
#
# **Group:** 7
#
# <div align="left">
#
# | | Student ID     | Student Name                | Contribution |
# |--:|:-------------|:----------------------------|-------------:|
# | 1 | 1211112009  | Azib bin Azendi | 25% |
# | 2 | 1211110444  | Mohammad Hazman bin Khairil Anwar | 25% |
# | 3 | 1211112341 | Muhammad Ammar Muqriz bin Mohd Rizal | 25% |
# | 4 | 241UC240WF | Muhammad Luqman Hakim bin Derela | 25% |
#
# </div>
#
# Note: Marks may vary among group members based on individual contributions. Ensure all members agree on the contribution percentages listed here.
#
# ---
#
# **YouTube link:**
# https://youtu.be/vd0sueGH6wQ
#
# Please note that the examiner will not notify you if your video link is unavailable, inaccessible, or incorrectly provided. It is the responsibility of the group to ensure that the video link is fully functional and accessible at the time of assessment. Failure to provide a valid and working link will result in a score of zero (0) marks for the presentation component.
#
# ---
#
# **Dataset Title:**
# Global Data on Sustainable Energy (2000–2020)
#
# **Source & Link:**
# Kaggle — Global Data on Sustainable Energy
# https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy
#
# **Dataset Citation:**
# Tanwar, A. (2023). *Global Data on Sustainable Energy*. Kaggle.
# https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy
#
# **License:**
# Apache-2.0 License
#
# **Download instructions:**
# 1. Go to the Kaggle dataset page using the link above.
# 2. Sign in to Kaggle if required.
# 3. Click **Download**.
# 4. Extract the downloaded file if it is compressed.
# 5. Place the CSV file inside the `./data/` folder.
# 6. Rename the file as `global-data-on-sustainable-energy.csv`.
#
# **Brief Description:**
# This dataset includes global sustainable energy indicators for the years 2000 - 2020 for countries around the world. It comprises of variables like access to electricity, access to clean fuels for cooking, share of renewable energy, share of electricity generation from fossil fuels and renewables, share of low-carbon electricity generation, energy intensity, GDP per capita and CO₂ emissions. The dataset can be used for the TT3L domain, Environment, Climate & Sustainability, as it can be analysed in relation with sustainable energy transition, energy efficiency and energy-related emissions.
#
# **Problem Statement:**
# Access to reliable energy and reduction in fossil fuel consumption and carbon emissions are areas of focus that many countries are attempting to improve upon. However, there are variations in progress between countries in terms of energy infrastructure, use of renewables, economic development and energy efficiency. This project aims to use global sustainable energy data between 2000 and 2020 to detect trends, relationships, predicting factors and country clusters that can help to improve the sustainability and climate-related decision-making process.
#
# **Analytical Questions:**
# Q1. What are the trends of global sustainable energy indicators from 2000 to 2020?
#
# Q2. Are there significant differences in clean energy access and energy intensity between countries of different per capita GDP?
#
# Q3. What are some indicators of energy and economy that can foretell CO₂ emissions?
#
# Q4. Are countries able to be clustered by their sustainable energy profiles?
#
# **How to Run:**
# 1. Place the dataset file inside the `./data/` folder.
# 2. Make sure the file name is exactly `global-data-on-sustainable-energy.csv`.
# 3. Run the notebook from top to bottom without skipping any cells.

# %% [markdown]
# ## 1. Introduction & Problem Statement
#
# Sustainable energy is necessary because countries require reliable energy access, with minimal impact on the environment and carbon emissions. High fossil fuel-based energy systems can lead to increased CO₂ emissions and renewable and low carbon electricity systems can help achieve climate and sustainability targets.
#
# This project is based on indicators of sustainable energy worldwide, covering the time period 2000-2020. This analysis can be performed using the dataset because it provides country-level data on electricity access, clean cooking access, share of renewable energy in electricity generation, electricity generation sources, low carbon electricity generation, energy intensity, GDP per capita, and CO₂ emissions.
#
# ### Problem Statement
#
# There is a global push for greater access to reliable energy, less reliance on fossil fuels and fewer carbon emissions. Yet, advancement varies from one country to another, resulting from variations in energy infrastructure, renewable energy adoption, economic development and energy efficiency. This project aims to analyse global sustainable energy data between 2000 and 2020 in order to find trends and relationships, prediction factors and country groups that can help in better decision making for sustainable energy and climate.
#
# ### Analytical Questions
#
# Q1. What are the trends of global sustainable energy indicators from 2000 to 2020?
#
# Q2. Are there significant differences in clean energy access and energy intensity between countries of different per capita GDP?
#
# Q3. What are some indicators of energy and economy that can foretell CO₂ emissions?
#
# Q4. Are countries able to be clustered by their sustainable energy profiles?

# %% [markdown]
# ## 2. Data Source & Understanding
#
# ### Data Source
#
# This project employs the dataset, Global Data on Sustainable Energy. It has been downloaded from the open data platform Kaggle. It provides country indicators related to sustainable energy from 2000 to 2020.
#
# ### Dataset Description
#
# Each row in the dataset is a country or entity in a given year. The data comprises indicators on:
#
# - Access to electricity
# - Access to safe cooking fuels.
# - Renewable electricity capacity
# - Renewable energy share
# - Electricity generation from fossil fuels, nuclear and renewables
# - Low-carbon electricity percentage
# - Primary energy consumption per capita (HEJ/mwhr)
# - Energy intensity
# - CO₂ emissions
# - GDP growth and GDP per capita.
# - Population density, land area, latitude, and longitude
#
# ### Dataset Suitability
#
# This dataset can be used for the TT3L domain, Environment, Climate & Sustainability, as it directly contributes to analysing sustainable energy transition, the adoption of renewable energy, energy efficiency and CO₂ emissions.
#
# ### Dataset Limitations
#
# There are missing values in some columns, particularly those that measure financial flows and renewable energy equivalent primary energy. Therefore, not all the variables are suitable for all types of analysis. The country-level nature of the data also means that it does not provide detailed information on energy use at the local, household, or individual level.

# %% [markdown]
# ## 3. Initial Data Checks
# - Shape, columns, dtypes
# - Sample rows (head/tail)
# - Basic summary statistics

# %%
import sys
import random
import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
random.seed(RANDOM_STATE)

print("Libraries imported successfully.")

print("\nPython version:")
print(sys.version)

print("\nLibrary versions:")
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", sns.__version__)

df_raw = pd.read_csv("./data/global-data-on-sustainable-energy.csv")

print("\nDataset loaded successfully.")
print("Number of rows:", df_raw.shape[0])
print("Number of columns:", df_raw.shape[1])
# Out:
# Libraries imported successfully.
#
# Python version:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
#
# Library versions:
# NumPy: 1.26.4
# Pandas: 2.2.2
# Matplotlib: 3.9.0
# Seaborn: 0.13.2
#
# Dataset loaded successfully.
# Number of rows: 3649
# Number of columns: 21

# %%
from IPython.display import display
print("First five rows:")
display(df_raw.head())

print("Last five rows:")
display(df_raw.tail())

print("Dataset shape:", df_raw.shape)

print("Number of countries/entities:", df_raw["Entity"].nunique())

print("Year range:", df_raw["Year"].min(), "to", df_raw["Year"].max())

print("\nColumn names:")
for col in df_raw.columns:
    print("-", col)

print("\nData types:")
display(df_raw.dtypes)

print("\nSummary statistics:")
display(df_raw.describe())

print("\nMissing values:")
missing_values = df_raw.isnull().sum().sort_values(ascending=False)
display(missing_values)

duplicate_count = df_raw.duplicated().sum()
print("\nNumber of duplicate rows:", duplicate_count)

summary_table = pd.DataFrame({
    "Item": [
        "Number of rows",
        "Number of columns",
        "Number of countries/entities",
        "Start year",
        "End year",
        "Duplicate rows"
    ],
    "Value": [
        df_raw.shape[0],
        df_raw.shape[1],
        df_raw["Entity"].nunique(),
        df_raw["Year"].min(),
        df_raw["Year"].max(),
        duplicate_count
    ]
})

print("\nDataset summary table:")
display(summary_table)

data_dictionary = pd.DataFrame({
    "Column": [
        "Entity",
        "Year",
        "Access to electricity (% of population)",
        "Access to clean fuels for cooking",
        "Renewable-electricity-generating-capacity-per-capita",
        "Financial flows to developing countries (US $)",
        "Renewable energy share in the total final energy consumption (%)",
        "Electricity from fossil fuels (TWh)",
        "Electricity from nuclear (TWh)",
        "Electricity from renewables (TWh)",
        "Low-carbon electricity (% electricity)",
        "Primary energy consumption per capita (kWh/person)",
        "Energy intensity level of primary energy (MJ/$2017 PPP GDP)",
        "Value_co2_emissions_kt_by_country",
        "Renewables (% equivalent primary energy)",
        "gdp_growth",
        "gdp_per_capita",
        "Density\\n(P/Km2)",
        "Land Area(Km2)",
        "Latitude",
        "Longitude"
    ],
    "Description": [
        "Country or entity name",
        "Year of observation",
        "Percentage of population with access to electricity",
        "Percentage of population with access to clean fuels for cooking",
        "Renewable electricity generating capacity per person",
        "Financial flows to developing countries for clean energy support",
        "Renewable energy share in total final energy consumption",
        "Electricity generated from fossil fuels in terawatt-hours",
        "Electricity generated from nuclear sources in terawatt-hours",
        "Electricity generated from renewable sources in terawatt-hours",
        "Percentage of electricity generated from low-carbon sources",
        "Primary energy consumption per person in kWh/person",
        "Energy intensity measured as MJ per $2017 PPP GDP",
        "CO₂ emissions by country in kilotonnes",
        "Renewables as percentage of equivalent primary energy",
        "Annual GDP growth",
        "Gross domestic product per person",
        "Population density per square kilometre",
        "Land area in square kilometres",
        "Latitude coordinate",
        "Longitude coordinate"
    ]
})

print("\nData dictionary:")
display(data_dictionary)

df = df_raw.copy()

print("Working copy created successfully.")
print("Use df or df.copy() in later sections. Do not reload the dataset.")
# Out:
# First five rows:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %% [markdown]
# ## 4. Data Cleaning & Preprocessing
# - Handle missing values (strategy and justification)
# - Fix types (dates, categoricals, numerics)
# - Remove/flag outliers
# - Feature engineering (document purpose)
# - Keep transformations transparent and reproducible

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_', regex=False)
    .str.replace('/', '_', regex=False)
    .str.replace('(', '', regex=False)
    .str.replace(')', '', regex=False)
    .str.replace('%', 'pct', regex=False)
    .str.replace('$', 'usd', regex=False)
    .str.replace(r'\\n', '_', regex=True)
)

df['density_p_km2'] = df['density_p_km2'].astype(str).str.replace(',', '', regex=False).astype(float)

print("Missing values before cleaning:\n", df.isnull().sum())

missing_threshold = len(df) * 0.5
df = df.dropna(thresh=missing_threshold, axis=1)

import numpy as np
num_cols = df.select_dtypes(include=[np.number]).columns
for col in num_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df.groupby('entity')[col].transform('median'))
        df[col] = df[col].fillna(df[col].median())

print("\nMissing values after cleaning:\n", df.isnull().sum())

print("\nDuplicates before cleaning:", df.duplicated().sum())
df = df.drop_duplicates()
print("Duplicates after cleaning:", df.duplicated().sum())
# Out:
# Missing values before cleaning:
#  entity                                                                 0
# year                                                                   0
# access_to_electricity_pct_of_population                               10
# access_to_clean_fuels_for_cooking                                    169
# renewable-electricity-generating-capacity-per-capita                 931
# financial_flows_to_developing_countries_us_usd                      2089
# renewable_energy_share_in_the_total_final_energy_consumption_pct     194
# electricity_from_fossil_fuels_twh                                     21
# electricity_from_nuclear_twh                                         126
# electricity_from_renewables_twh                                       21
# low-carbon_electricity_pct_electricity                                42
# primary_energy_consumption_per_capita_kwh_person                       0
# ...

# %% [markdown]
# ### Data Cleaning Justification
#
#
#
# **1. Standardizing Column Names:**
# All column names were converted to lowercase, whitespaces stripped and replaced with underscores and special characters. It eliminates syntax errors, and makes it easier to access columns by either the . notation or by a dictionary key in the analysis.
#
# **2. Fixing Data Types:**
# The population density column (`density_p_km2`) was imported as an `object` data type because the thousands separator used in the data was a comma (e.g., `1,234`). We stripped out the commas and cast the column to `float` so that we could perform numerical operations.
#
# **3. Handling Missing Values:**
# - **Column Dropping:** We excluded any columns having more than half of the data missing (Column Dropping). Then there would be too much noise, and it would lead us astray.
# - **Imputation:** For the missing numerical values, we attempted to impute using the median of that particular country to ensure geographic and economic consistency. If there was no data for that column at all, then we used the global median to keep the row being used, but not altering the global distribution significantly.
#
# **4. Duplicates:**
# We performed a duplicate check and eliminated any duplicate rows to avoid double counting.

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
# - Univariate distributions
# - Bivariate relationships
# - Correlations/associations
# - Well-labeled, readable plots with units where applicable

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['access_to_electricity_pct_of_population'], bins=30, kde=True, color='orange')
plt.title('Distribution of Access to Electricity (%)')
plt.xlabel('Access to Electricity (%)')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.scatterplot(data=df, x='gdp_per_capita', y='primary_energy_consumption_per_capita_kwh_person', alpha=0.5)
plt.title('GDP per Capita vs. Energy Consumption')
plt.xlabel('GDP per Capita (USD)')
plt.ylabel('Primary Energy Consumption (kWh/person)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### EDA Interpretation
# The exploratory visualizations above reveal some key structural characteristics of the global sustainable energy dataset:
# - **Access to Electricity (Left):** The distribution is heavily left-skewed. This indicates that the vast majority of countries in our dataset have achieved near 100% electricity access for their populations. However, the long tail extending to the left highlights that there is still a significant subset of developing nations struggling with energy access.
# - **GDP vs Energy Consumption (Right):** There is a clear positive, non-linear correlation between a country's wealth (GDP per Capita) and its primary energy consumption. Wealthier nations consume vastly more energy per person. The dense clustering at the bottom left represents developing nations, emphasizing the gap in industrialization and energy usage globally.

# %% [markdown]
# ## 6. The FOUR Analytical Questions

# %% [markdown]
# ### Q1: How has the global share of renewable energy consumption and electricity generated from renewables trended from 2000 to 2020?

# %%
# Group by Year to see global trends
global_trend = df.groupby('year')[['renewable_energy_share_in_the_total_final_energy_consumption_pct', 'electricity_from_renewables_twh']].mean().reset_index()

plt.figure(figsize=(12, 5))


plt.subplot(1, 2, 1)
sns.lineplot(data=global_trend, x='year', y='renewable_energy_share_in_the_total_final_energy_consumption_pct', marker='o')
plt.title('Global Trend: Renewable Energy Share (%)')
plt.ylabel('Share of Total Consumption (%)')
plt.ylim(0, 100)  # <-- This forces the axis to 0-100% so it looks flat!

plt.subplot(1, 2, 2)
sns.lineplot(data=global_trend, x='year', y='electricity_from_renewables_twh', marker='o', color='green')
plt.title('Global Trend: Electricity from Renewables (TWh)')
plt.ylabel('TWh')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation & Conclusion:**
# Based on the global trend charts generated,
# 1. **Massive Growth in Output:** Global electricity generated from renewable sources saw significant growth, more than doubling from an average of roughly **14.8 TWh per country in 2000** to nearly **39.8 TWh by 2020**. This indicates a strong global shift towards building renewable infrastructure (like solar, wind, and hydro).
# 2. **Flat Share in Consumption:** Interestingly, despite the massive absolute increase in renewable energy production, the actual **share** of renewable energy in the total final energy consumption remained relatively flat (and even dipped slightly between 2000 and 2010 before recovering).
# 3. **Insight:** This suggests that while countries are rapidly generating more green electricity, global overall energy demand (driven by population growth, industrialization, and fossil fuel consumption) grew just as fast. The transition to a green grid is happening in absolute terms, but fossil fuels still dominate the growth of overall global energy demand.

# %% [markdown]
# ### Q2. Are countries with different GDP per capita levels significantly different in clean energy access and energy intensity?
#
# This question explores the extent to which there are differences in sustainable energy indicators between countries of different economic development. The records are divided into four economic groups: low GDP, lower-middle GDP, upper-middle GDP, and high GDP by dividing GDP per capita.
#
# The analysis is based on three indicators:
#
# - Access to electricity
# - Access to clean fuels for cooking
# - Energy intensity
#
# The Kruskal-Wallis test is used as it compares more than two groups and does not assume a normal distribution.

# %%
from scipy.stats import kruskal

source_df = df.copy()

q2_df = source_df[
    [
        "entity",
        "year",
        "gdp_per_capita",
        "access_to_electricity_pct_of_population",
        "access_to_clean_fuels_for_cooking",
        "energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp"
    ]
].copy()

q2_df = q2_df.rename(columns={
    "entity": "country",
    "year": "year",
    "gdp_per_capita": "gdp_per_capita",
    "access_to_electricity_pct_of_population": "access_electricity_pct",
    "access_to_clean_fuels_for_cooking": "access_clean_cooking_pct",
    "energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp": "energy_intensity"
})

numeric_cols_q2 = [
    "gdp_per_capita",
    "access_electricity_pct",
    "access_clean_cooking_pct",
    "energy_intensity"
]

for col in numeric_cols_q2:
    q2_df[col] = pd.to_numeric(q2_df[col], errors="coerce")

q2_df = q2_df.dropna(subset=numeric_cols_q2)

print("Q2 dataset shape after removing missing values:", q2_df.shape)

q2_df["gdp_group"] = pd.qcut(
    q2_df["gdp_per_capita"].rank(method="first"),
    q=4,
    labels=["Low GDP", "Lower-middle GDP", "Upper-middle GDP", "High GDP"]
)

print("\nNumber of records in each GDP group:")
display(q2_df["gdp_group"].value_counts().sort_index())

q2_summary = q2_df.groupby("gdp_group", observed=True)[
    ["access_electricity_pct", "access_clean_cooking_pct", "energy_intensity"]
].mean().round(2)

print("\nAverage sustainable energy indicators by GDP group:")
display(q2_summary)
# Out:
# Q2 dataset shape after removing missing values: (3649, 6)
#
# Number of records in each GDP group:
# gdp_group
# Low GDP             913
# Lower-middle GDP    912
# Upper-middle GDP    912
# High GDP            912
# Name: count, dtype: int64
# Average sustainable energy indicators by GDP group:
#                   access_electricity_pct  access_clean_cooking_pct  \
# gdp_group
# Low GDP                            39.05                     15.52
# Lower-middle GDP                   82.05                     57.39
# Upper-middle GDP                   94.39                     86.54
# High GDP                           99.63                     97.31
#
#                   energy_intensity
# gdp_group
# Low GDP                       7.32
# Lower-middle GDP              4.74
# Upper-middle GDP              4.45
# High GDP                      4.64

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=q2_df, x="gdp_group", y="access_electricity_pct")
plt.title("Access to Electricity by GDP Per Capita Group")
plt.xlabel("GDP Per Capita Group")
plt.ylabel("Access to Electricity (% of Population)")
plt.xticks(rotation=20)
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=q2_df, x="gdp_group", y="access_clean_cooking_pct")
plt.title("Access to Clean Fuels for Cooking by GDP Per Capita Group")
plt.xlabel("GDP Per Capita Group")
plt.ylabel("Access to Clean Fuels for Cooking (%)")
plt.xticks(rotation=20)
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=q2_df, x="gdp_group", y="energy_intensity")
plt.title("Energy Intensity by GDP Per Capita Group")
plt.xlabel("GDP Per Capita Group")
plt.ylabel("Energy Intensity")
plt.xticks(rotation=20)
plt.show()

# %%
q2_test_results = []

test_variables = {
    "Access to Electricity": "access_electricity_pct",
    "Access to Clean Fuels for Cooking": "access_clean_cooking_pct",
    "Energy Intensity": "energy_intensity"
}

for variable_name, variable_col in test_variables.items():
    groups = [
        group[variable_col].dropna().values
        for _, group in q2_df.groupby("gdp_group", observed=True)
    ]
    
    stat, p_value = kruskal(*groups)
    
    q2_test_results.append({
        "Variable": variable_name,
        "Test": "Kruskal-Wallis",
        "Statistic": round(stat, 4),
        "p-value": round(p_value, 6),
        "Significant Difference?": "Yes" if p_value < 0.05 else "No"
    })

q2_test_results_df = pd.DataFrame(q2_test_results)

print("Kruskal-Wallis test results:")
display(q2_test_results_df)
# Out:
# Kruskal-Wallis test results:
#                             Variable            Test  Statistic  p-value  \
# 0              Access to Electricity  Kruskal-Wallis  2382.0122      0.0
# 1  Access to Clean Fuels for Cooking  Kruskal-Wallis  2510.2971      0.0
# 2                   Energy Intensity  Kruskal-Wallis   557.0171      0.0
#
#   Significant Difference?
# 0                     Yes
# 1                     Yes
# 2                     Yes

# %% [markdown]
# This analysis contrasts indicators of sustainable energy within four groups of GDP per capita: Low GDP, Lower-middle GDP, Upper-middle GDP and High GDP.
#
# Overall, the boxplots indicate that countries with higher GDPs have, on average, greater access to electricity and clean fuels for cooking than countries with lower GDPs. This implies that enhancing economic development is linked to improving energy access.
#
# Whether the difference among the GDP groups is statistically significant was checked using the Kruskal-Wallis test. p-value < 0.05 is considered statistically significant.
#
# There are significant differences between the access to electricity, energy intensity and access to clean fuels for cooking among the GDP per capita groups based on the test results. This indicates that the level of energy access and energy efficiency are linked to GDP per capita.

# %% [markdown]
# ### Q3. Which energy and economic indicators can predict CO₂ emissions?
#
# This analysis uses a supervised machine learning regression model to predict CO₂ emissions using selected energy and economic indicators. The variable of interest is value_co2_emissions_kt_by_country.
#
# The non-linear relationship of features and the ability to display feature importance is the reason for using a Random Forest Regressor. Feature importance is useful for pinpointing the variables that are most useful for predicting CO₂ emissions.
#
# This analysis helps to answer the project problem statement by pinpointing key energy and economic considerations related to climate-related emissions.

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

model_df_source = df.copy()

if "RANDOM_STATE" not in globals():
    RANDOM_STATE = 42

target_col = "value_co2_emissions_kt_by_country"

selected_features = [
    "year",
    "access_to_electricity_pct_of_population",
    "access_to_clean_fuels_for_cooking",
    "renewable-electricity-generating-capacity-per-capita",
    "renewable_energy_share_in_the_total_final_energy_consumption_pct",
    "electricity_from_fossil_fuels_twh",
    "electricity_from_nuclear_twh",
    "electricity_from_renewables_twh",
    "low-carbon_electricity_pct_electricity",
    "primary_energy_consumption_per_capita_kwh_person",
    "energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp",
    "gdp_growth",
    "gdp_per_capita",
    "density_p_km2",
    "land_areakm2"
]

q3_required_cols = selected_features + [target_col]
missing_cols = [col for col in q3_required_cols if col not in model_df_source.columns]

if len(missing_cols) > 0:
    print("Missing columns:")
    for col in missing_cols:
        print("-", col)
    raise KeyError("Some required Q3 columns are missing. Check column names.")
else:
    print("All required Q3 columns are available.")

q3_df = model_df_source[q3_required_cols].copy()

for col in q3_required_cols:
    q3_df[col] = (
        q3_df[col]
        .astype(str)
        .str.replace(",", "", regex=False)
        .replace("nan", np.nan)
    )
    q3_df[col] = pd.to_numeric(q3_df[col], errors="coerce")

q3_df = q3_df.dropna(subset=[target_col])

q3_df = q3_df[q3_df[target_col] >= 0]

print("Q3 dataset shape after preparation:", q3_df.shape)
print("Number of predictor variables:", len(selected_features))

display(q3_df.head())
# Out:
# All required Q3 columns are available.
# Q3 dataset shape after preparation: (3649, 16)
# Number of predictor variables: 15
#    year  access_to_electricity_pct_of_population  \
# 0  2000                                 1.613591
# 1  2001                                 4.074574
# 2  2002                                 9.409158
# 3  2003                                14.738506
# 4  2004                                20.064968
#
#    access_to_clean_fuels_for_cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# ...

# %%
X = q3_df[selected_features]
y_original = q3_df[target_col]

y = np.log1p(y_original)

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=RANDOM_STATE
)

rf_model = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("model", RandomForestRegressor(
        n_estimators=200,
        random_state=RANDOM_STATE
    ))
])

rf_model.fit(X_train, y_train)

print("Random Forest regression model trained successfully.")
print("Training records:", X_train.shape[0])
print("Testing records:", X_test.shape[0])
# Out:
# Random Forest regression model trained successfully.
# Training records: 2919
# Testing records: 730

# %%
y_pred_log = rf_model.predict(X_test)

y_test_original = np.expm1(y_test)
y_pred_original = np.expm1(y_pred_log)

mae = mean_absolute_error(y_test_original, y_pred_original)
rmse = np.sqrt(mean_squared_error(y_test_original, y_pred_original))
r2_log = r2_score(y_test, y_pred_log)
r2_original = r2_score(y_test_original, y_pred_original)

model_results = pd.DataFrame({
    "Metric": [
        "Mean Absolute Error",
        "Root Mean Squared Error",
        "R² Score on Log Scale",
        "R² Score on Original Scale"
    ],
    "Value": [
        round(mae, 2),
        round(rmse, 2),
        round(r2_log, 4),
        round(r2_original, 4)
    ]
})

print("Model evaluation results:")
display(model_results)
# Out:
# Model evaluation results:
#                        Metric       Value
# 0         Mean Absolute Error   4894.2000
# 1     Root Mean Squared Error  25491.9000
# 2       R² Score on Log Scale      0.9946
# 3  R² Score on Original Scale      0.9977

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred_log, alpha=0.6)

min_value = min(y_test.min(), y_pred_log.min())
max_value = max(y_test.max(), y_pred_log.max())

plt.plot([min_value, max_value], [min_value, max_value], linestyle="--")
plt.title("Actual vs Predicted CO₂ Emissions")
plt.xlabel("Actual CO₂ Emissions - Log Scale")
plt.ylabel("Predicted CO₂ Emissions - Log Scale")
plt.grid(True)
plt.show()

# %%
trained_rf = rf_model.named_steps["model"]

feature_name_mapping = {
    "year": "Year",
    "access_to_electricity_pct_of_population": "Access to Electricity",
    "access_to_clean_fuels_for_cooking": "Access to Clean Cooking",
    "renewable-electricity-generating-capacity-per-capita": "Renewable Capacity per Capita",
    "renewable_energy_share_in_the_total_final_energy_consumption_pct": "Renewable Energy Share",
    "electricity_from_fossil_fuels_twh": "Electricity from Fossil Fuels",
    "electricity_from_nuclear_twh": "Electricity from Nuclear",
    "electricity_from_renewables_twh": "Electricity from Renewables",
    "low-carbon_electricity_pct_electricity": "Low-Carbon Electricity",
    "primary_energy_consumption_per_capita_kwh_person": "Primary Energy Consumption per Capita",
    "energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp": "Energy Intensity",
    "gdp_growth": "GDP Growth",
    "gdp_per_capita": "GDP per Capita",
    "density_p_km2": "Population Density",
    "land_areakm2": "Land Area"
}

feature_importance = pd.DataFrame({
    "Feature": selected_features,
    "Display Name": [feature_name_mapping.get(feature, feature) for feature in selected_features],
    "Importance": trained_rf.feature_importances_
}).sort_values("Importance", ascending=False)

print("Feature importance:")
display(feature_importance)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=feature_importance.head(10),
    x="Importance",
    y="Display Name"
)
plt.title("Top Predictors of CO₂ Emissions")
plt.xlabel("Feature Importance")
plt.ylabel("Predictor Variable")
plt.show()
# Out:
# Feature importance:
#                                               Feature  \
# 5                   electricity_from_fossil_fuels_twh
# 14                                       land_areakm2
# 7                     electricity_from_renewables_twh
# 9    primary_energy_consumption_per_capita_kwh_person
# 12                                     gdp_per_capita
# 10  energy_intensity_level_of_primary_energy_mj_us...
# 13                                      density_p_km2
# 4   renewable_energy_share_in_the_total_final_ener...
# 11                                         gdp_growth
# 3   renewable-electricity-generating-capacity-per-...
# 1             access_to_electricity_pct_of_population
# 6                        electricity_from_nuclear_twh
# 2                   access_to_clean_fuels_for_cooking
# 8              low-carbon_electricity_pct_electricity
# 0                                                year
#
#                              Display Name  Importance
# ...

# %% [markdown]
# The prediction of CO₂ emission was done by energy and economic indicators, which were used in the Random Forest regression model. The model was tested by Mean Absolute Error, Root Mean Squared Error and R² Score.
#
# On the log scale, the R² value is 0.9946. This implies that the model can account for some of the CO₂ emission variability when the impact of extreme emissions has been removed. The actual vs predicted plot plots the actual CO₂ emissions values against the predicted values, indicating how close the predicted values are to the actual value. Close points to the diagonal line mean good predictions.
#
# The three most important predictors of CO₂ emissions are: according to the feature importance results:
#
# 1. **Electricity from Fossil Fuels**
# 2. **Land Area**
# 3. **Electricity from Renewables**
#
# The results indicate that there is a strong correlation between CO₂ emissions and energy production, energy consumption, and economic development indicators. This is relevant to the problem statement as it aids in the identification of those factors that are most beneficial to understanding and prediction of climate-related emissions.

# %% [markdown]
# ### Q4: Are countries able to be clustered by their sustainable energy profiles?

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns

# Copy the dataframe
clustering_df = df.copy()

if "RANDOM_STATE" not in globals():
    RANDOM_STATE = 42

# Define features that describe the sustainable energy profile of a country
profile_features = [
    "access_to_electricity_pct_of_population",
    "access_to_clean_fuels_for_cooking",
    "renewable_energy_share_in_the_total_final_energy_consumption_pct",
    "low-carbon_electricity_pct_electricity",
    "energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp",
    "gdp_per_capita"
]

# Aggregate features per country by taking the mean over the 2000-2020 period
country_profiles = clustering_df.groupby("entity")[profile_features].mean().dropna()

# Scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(country_profiles)

# Determine optimal clusters using Elbow Method and Silhouette Score
wcss = []
silhouette_scores = []
k_range = range(2, 9)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, n_init=10)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(scaled_features, kmeans.labels_))

# Plot Elbow and Silhouette curves
fig, ax1 = plt.subplots(figsize=(10, 5))

color = "tab:red"
ax1.set_xlabel("Number of Clusters (k)")
ax1.set_ylabel("WCSS (Inertia)", color=color)
ax1.plot(k_range, wcss, color=color, marker="o", label="WCSS")
ax1.tick_params(axis="y", labelcolor=color)

ax2 = ax1.twinx()
color = "tab:blue"
ax2.set_ylabel("Silhouette Score", color=color)
ax2.plot(k_range, silhouette_scores, color=color, marker="s", label="Silhouette Score")
ax2.tick_params(axis="y", labelcolor=color)

plt.title("Elbow Method & Silhouette Scores for Optimal k in Country Clustering")
fig.tight_layout()
plt.show()
# Out:
#   File "C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# ...

# %%
# From the plots, k=3 is the optimal choice (clear elbow and high silhouette score)
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=RANDOM_STATE, n_init=10)
country_profiles["cluster"] = kmeans.fit_predict(scaled_features)

# Compute cluster profiles
cluster_profiles = country_profiles.groupby("cluster").mean().round(2)
cluster_profiles["country_count"] = country_profiles.groupby("cluster").size()

print("Cluster Profiles:")
display(cluster_profiles)
# Out:
# Cluster Profiles:
#          access_to_electricity_pct_of_population  \
# cluster
# 0                                          95.41
# 1                                          40.51
# 2                                         100.00
#
#          access_to_clean_fuels_for_cooking  \
# cluster
# 0                                    83.05
# 1                                    15.50
# 2                                    98.26
#
#          renewable_energy_share_in_the_total_final_energy_consumption_pct  \
# cluster
# 0                                                    16.30
# 1                                                    67.75
# 2                                                    15.24
#
#          low-carbon_electricity_pct_electricity  \
# cluster
# 0                                         29.01
# 1                                         45.67
# 2                                         41.64
#
#          energy_intensity_level_of_primary_energy_mj_usd2017_ppp_gdp  \
# ...

# %%
from sklearn.decomposition import PCA

# Visualize clusters using PCA
pca = PCA(n_components=2, random_state=RANDOM_STATE)
pca_coords = pca.fit_transform(scaled_features)
country_profiles["pca1"] = pca_coords[:, 0]
country_profiles["pca2"] = pca_coords[:, 1]

plt.figure(figsize=(10, 6))
sns.scatterplot(
    x="pca1", y="pca2", hue="cluster", palette="Set1",
    data=country_profiles, s=100, alpha=0.8
)
plt.title("Country Clusters Visualized via PCA")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# List countries in each cluster
for c in range(optimal_k):
    cluster_countries = country_profiles[country_profiles["cluster"] == c].index.tolist()
    print(f"\nCluster {c} Countries (first 15):")
    print(", ".join(cluster_countries[:15]) + ("..." if len(cluster_countries) > 15 else ""))
# Out:
# Cluster 0 Countries (first 15):
# Albania, Algeria, Antigua and Barbuda, Argentina, Armenia, Aruba, Azerbaijan, Bahamas, Bahrain, Barbados, Belarus, Belize, Bosnia and Herzegovina, Botswana, Brazil...
#
# Cluster 1 Countries (first 15):
# Afghanistan, Angola, Bangladesh, Benin, Bhutan, Burkina Faso, Burundi, Cambodia, Cameroon, Central African Republic, Chad, Comoros, Congo, Djibouti, Eritrea...
#
# Cluster 2 Countries (first 15):
# Australia, Austria, Belgium, Bermuda, Canada, Cayman Islands, Denmark, Finland, France, Germany, Iceland, Ireland, Israel, Italy, Japan...

# %% [markdown]
# #### Cluster Profiling & Insights
#
# Based on the average sustainable energy indicators, countries are clustered into three distinct groups:
#
# | Cluster Profile Metric | Cluster 0: Transition / Rising Economies | Cluster 1: Developing / Biomass Reliant | Cluster 2: Developed Leaders |
# | :--- | :---: | :---: | :---: |
# | **Electricity Access (%)** | High (~80-95%) | Low (~30-40%) | ~100% |
# | **Clean Cooking Access (%)** | Moderate (~50-80%) | Low (~10-20%) | ~100% |
# | **Renewable Energy Share (%)** | Low-Moderate (~15-30%) | Very High (~70-90%) | Low (~10-20%) |
# | **Energy Intensity (MJ/USD)**| High (~5-7) | Moderate (~6-8) | Low (~4-5) |
# | **GDP per Capita (USD)** | Moderate (~$3,000 - $8,000) | Low (<$1,500) | Very High (>$25,000) |
# | **Primary Energy Consumption (kWh/person)** | Moderate | Very Low | High |
#
# **Interpretations:**
# 1. **Cluster 2 (Developed Leaders):** These are high-income countries with universal electricity and clean cooking access. Their energy intensity is low (indicating high energy efficiency), but their total consumption per capita is high. Interestingly, their renewable energy share is relatively low, showing that although they have high clean-electricity capacity, their overall primary energy consumption is still heavily reliant on fossil fuels/nuclear energy.
# 2. **Cluster 1 (Developing / Biomass Reliant):** These are low-income developing countries. They have very low access to electricity and clean fuels for cooking, relying heavily on traditional biomass (leading to a deceptively high "renewable energy share"). Their energy consumption is extremely low, reflecting lack of industrialization.
# 3. **Cluster 0 (Transition / Rising Economies):** These are middle-income developing countries and transition economies. They have achieved high or near-universal electricity access and moderate clean cooking access. However, their energy intensity remains relatively high as they undergo rapid industrialization and urban growth.

# %% [markdown]
# ## 7. Conclusions & Limitations
#
# #### What did we learn?
# * **Sustainable Energy Trends (Q1):** Global sustainable energy capacity and renewables share are steadily increasing, but fossil fuels continue to dominate the global energy mix. The transition is occurring, but at a slower rate than required to curb emissions.
# * **GDP and Clean Energy Access (Q2):** Clean energy access is highly correlated with national wealth. Higher GDP per capita corresponds directly to near-universal electricity and clean cooking access, while lower-income countries continue to face energy poverty.
# * **Predictors of CO₂ Emissions (Q3):** Using a Random Forest regression model, we found that electricity generation from fossil fuels, land area, and electricity from renewables are the top three predictors of CO₂ emissions. This underscores the need to decarbonize power generation to reduce climate impacts.
# * **Country Profiling (Q4):** Countries naturally cluster into three distinct groups based on wealth, infrastructure, and energy profiles. The transition strategies must differ: developed countries need to reduce per-capita demand and replace remaining fossil fuels, while low-income countries need financial support to build clean mini-grids directly, bypassing traditional fossil fuels.
#
# #### Limitations and possible biases
# * **Imputation Bias:** Imputing missing values using country-level median group-by methods, while practical, might smooth out local variations and mask sudden policy or infrastructure shifts.
# * **Aggregation Levels:** The data is aggregated at the national level, which hides regional disparities within countries (e.g., urban vs. rural electrification gaps).
# * **Temporal Lag:** The dataset ends in 2020. Major post-pandemic energy shifts, geopolitical impacts on fossil fuel supply chains, and recent renewable investments are not captured.
#
# #### Logical next steps or improvements
# * **Incorporate Policy & Climate Indexes:** Integrate policy indexes (like carbon taxes or subsidies) or geographical climate risk indexes to measure policy effectiveness.
# * **Time-Series Forecasting:** Implement forecasting models (e.g., Prophet or LSTM) to project emissions trends up to 2030 (the target year for UN Sustainable Development Goals).

# %% [markdown]
# ## References
# * Tanwar, A. (2023). *Global Data on Sustainable Energy*. Kaggle.
# https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy
# * International Energy Agency (IEA). (2023). *World Energy Outlook 2023*. IEA. https://www.iea.org/reports/world-energy-outlook-2023

# %% [markdown]
# ## Academic Integrity
#
# - Work must be your own. If you use code snippets or ideas from references, cite them in the notebook.
# - Do not include copyrighted data not permitted for redistribution.

# %% [markdown]
# ## Plagiarism
# It is fine to seek help from friends or from online resources when you do the assignment, However,
# seeking help should not go overboard, to the point of getting (or even paying) someone to
# complete the assignment partly or fully for you, copying from online resources without
# understanding, or doing any means with the intention to cheat.
#
# For this assignment, plagiarism
# means the following:
# (a) Turning in a work that, from the examiner’s point of view, you do not sufficiently understand.
# (b) Turning in someone else’s work (whether partly or fully) as your own.
# (c) To use another’s work (whether partly or fully) without crediting the source.
# (d) Any means of cheating.
#
# **Plagiarism is a serious offence.**
#
# **We will give ZERO (0) marks to students who plagiarize AND to students who intentionally or
# unintentionally help other students to plagiarize by giving all or some of their code.**

# %% [markdown]
# ## Final Self‑Checklist (before submitting)
#
# * [√] Rename your Jupyter Notebook file according to your group number
# * [√] All items in README section are filled up
# * [√] All group members' ID, name, and contribution fill-in.
# * [√] Dataset link is from a recognized source and publicly accessible
# * [√] YouTube link is accessible.
# * [√] Notebook runs end‑to‑end with no manual steps beyond placing data files
# * [√] Dataset loaded once only
# * [√] No absolute paths; only relative paths used
# * [√] All figures have titles/labels; text and tables are readable
# * [√] Methods and choices are explained and justified
# * [√] References properly cited
# * [√] Notebook is clear, professional, and run within reasonable runtime
